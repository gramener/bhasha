# %%
import numpy as np
import imageio as io
import matplotlib.pyplot as plt
import cv2
import textwrap
from typing import List
from pygifsicle import optimize
from PIL import Image, ImageDraw, ImageFont

# %matplotlib inline

# %%
from pathlib import Path
CWD = Path('.')
DATA = CWD/'data'
OUT = CWD/'out'
# !ls {DATA}
# Out:
#  covid_spread.json		       fonts
# 'covid-spread - social-distance.csv'   src
# 'covid-spread - symptom.csv'	       symptom.json

# %%
# !ls {DATA/'src'}
# Out:
# covid_spread.gif  flatcurve2.gif  handshake.gif
# distance.gif	  flatcurve.gif   symptom.png

# %%
symptom = Image.open(DATA/'src'/'symptom.png')

# %%
fig, ax = plt.subplots(figsize=(15,15))
ax.xaxis.set_ticks(ticks=np.arange(0, 1704, 25))
ax.yaxis.set_ticks(ticks=np.arange(0, 1098, 25))
ax.grid(b=True)
plt.xticks(rotation=90)
plt.imshow(symptom)
